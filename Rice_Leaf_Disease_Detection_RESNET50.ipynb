# %% [markdown]
# <a href="https://colab.research.google.com/github/shadmanshakib09/Rice-Leaf-Disease-Detection/blob/main/Rice_Leaf_Disease_Detection_RESNET50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Md. Shadman Shakib
# Lecturer, Metropolitan University, Sylhet, Bangladesh

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# %cd CONFERENCE1
# Out:
# /content/gdrive/.shortcut-targets-by-id/14iSH-uYVIsSWIRZ3acFwjZ39HjpSY0kt/CONFERENCE1

# %%
import random
import cv2 as cv
import tensorflow as tf
import numpy as np
import pandas as pd
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing import image
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.applications import InceptionV3

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16


CHANNELS = 3

# %%
data_dir = '/content/gdrive/MyDrive/CONFERENCE1/train2/'

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 4702 files belonging to 3 classes.

# %%
class_names = dataset.class_names
print(class_names)
print(f'Total length of dataset: {len(dataset)}')
# Out:
# ['BACTERIAL BLIGHT', 'BLAST', 'BROWNSPOT']
# Total length of dataset: 294

# %%
train_size = 0.8
print(f'Train dataset size: {len(dataset)*train_size}')
train_ds = dataset.take(235)
test_ds = dataset.skip(235)
print(f'Test dataset size: {len(test_ds)}')
val_size = 0.1
# print(len(dataset)*val_size)
val_ds = test_ds.take(30)
print(f'Val dataset size: {len(val_ds)}')
test_ds = test_ds.skip(30)
print(f'Test dataset size: {len(test_ds)}')
# Out:
# Train dataset size: 235.20000000000002
# Test dataset size: 59
# Val dataset size: 30
# Test dataset size: 29

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = 30
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    print(len(val_ds))
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
# Out:
# 30

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE,IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
epochs = 100
num_classes = 3

# %%
model1 = Sequential()

pretrained_model = tf.keras.applications.ResNet50(include_top=False,
                               input_shape=(224,224, 3),
                               pooling='avg', classes=3,
                               weights='imagenet')
print(len(pretrained_model.layers))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# 176

# %%
for layer in pretrained_model.layers:
    layer.trainable = False
model1.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(224,224, 3)))
model1.add(pretrained_model)
model1.add(layers.Flatten())
model1.add(layers.Dense(256, activation='relu'))
model1.add(layers.Dense(128, activation='relu'))
model1.add(layers.Dense(64, activation='relu'))
model1.add(layers.Dense(num_classes, activation='softmax'))
model1.compile(optimizer='adam',
               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
               metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 224, 224, 3)       0
#
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 24153603 (92.14 MB)
# Trainable params: 565891 (2.16 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
history1 = model1.fit(
train_ds,
validation_data=val_ds,
epochs=epochs
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/backend.py:5727: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 235/235 [==============================] - 517s 234ms/step - loss: 1.1013 - accuracy: 0.3561 - val_loss: 1.0801 - val_accuracy: 0.3979
# Epoch 2/100
# 235/235 [==============================] - 13s 55ms/step - loss: 1.0645 - accuracy: 0.4170 - val_loss: 1.0227 - val_accuracy: 0.4708
# Epoch 3/100
# 235/235 [==============================] - 13s 56ms/step - loss: 1.0436 - accuracy: 0.4441 - val_loss: 1.0067 - val_accuracy: 0.4750
# Epoch 4/100
# 235/235 [==============================] - 13s 56ms/step - loss: 1.0190 - accuracy: 0.4495 - val_loss: 1.0128 - val_accuracy: 0.4771
# Epoch 5/100
# 235/235 [==============================] - 13s 56ms/step - loss: 1.0167 - accuracy: 0.4415 - val_loss: 0.9901 - val_accuracy: 0.4646
# Epoch 6/100
# 235/235 [==============================] - 13s 57ms/step - loss: 1.0040 - accuracy: 0.4625 - val_loss: 0.9741 - val_accuracy: 0.4688
# Epoch 7/100
# 235/235 [==============================] - 13s 57ms/step - loss: 1.0018 - accuracy: 0.4753 - val_loss: 0.9874 - val_accuracy: 0.4771
# Epoch 8/100
# 235/235 [==============================] - 13s 56ms/step - loss: 0.9979 - accuracy: 0.4622 - val_loss: 0.9772 - val_accuracy: 0.4812
# Epoch 9/100
# 235/235 [==============================] - 13s 57ms/step - loss: 0.9878 - accuracy: 0.4761 - val_loss: 0.9641 - val_accuracy: 0.4958
# Epoch 10/100
# 235/235 [==============================] - 13s 57ms/step - loss: 0.9883 - accuracy: 0.4694 - val_loss: 0.9808 - val_accuracy: 0.4854
# Epoch 11/100
# 235/235 [==============================] - 13s 57ms/step - loss: 0.9892 - accuracy: 0.4766 - val_loss: 0.9625 - val_accuracy: 0.4688
# Epoch 12/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9789 - accuracy: 0.4870 - val_loss: 0.9572 - val_accuracy: 0.4938
# Epoch 13/100
# 235/235 [==============================] - 14s 57ms/step - loss: 0.9780 - accuracy: 0.4880 - val_loss: 0.9473 - val_accuracy: 0.4896
# Epoch 14/100
# 235/235 [==============================] - 13s 57ms/step - loss: 0.9778 - accuracy: 0.4827 - val_loss: 0.9797 - val_accuracy: 0.4833
# Epoch 15/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9705 - accuracy: 0.4835 - val_loss: 0.9618 - val_accuracy: 0.4958
# Epoch 16/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.9637 - accuracy: 0.4904 - val_loss: 1.0119 - val_accuracy: 0.4479
# Epoch 17/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9775 - accuracy: 0.4894 - val_loss: 0.9557 - val_accuracy: 0.4938
# Epoch 18/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9624 - accuracy: 0.4864 - val_loss: 0.9380 - val_accuracy: 0.5083
# Epoch 19/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9668 - accuracy: 0.4888 - val_loss: 0.9654 - val_accuracy: 0.5000
# Epoch 20/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9583 - accuracy: 0.4936 - val_loss: 0.9621 - val_accuracy: 0.4667
# Epoch 21/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.9566 - accuracy: 0.4875 - val_loss: 0.9352 - val_accuracy: 0.5021
# Epoch 22/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9537 - accuracy: 0.5029 - val_loss: 0.9424 - val_accuracy: 0.4896
# Epoch 23/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.9516 - accuracy: 0.5045 - val_loss: 0.9250 - val_accuracy: 0.5208
# Epoch 24/100
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9346 - accuracy: 0.5106 - val_loss: 0.9423 - val_accuracy: 0.5063
# Epoch 25/100
# 235/235 [==============================] - 15s 62ms/step - loss: 0.9399 - accuracy: 0.5096 - val_loss: 0.9208 - val_accuracy: 0.5250
# Epoch 26/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9303 - accuracy: 0.5202 - val_loss: 0.9326 - val_accuracy: 0.5208
# Epoch 27/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.9366 - accuracy: 0.5128 - val_loss: 0.9268 - val_accuracy: 0.5292
# Epoch 28/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9290 - accuracy: 0.5056 - val_loss: 0.9207 - val_accuracy: 0.5229
# Epoch 29/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9216 - accuracy: 0.5234 - val_loss: 0.9049 - val_accuracy: 0.5271
# Epoch 30/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9229 - accuracy: 0.5247 - val_loss: 0.9019 - val_accuracy: 0.5312
# Epoch 31/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.9187 - accuracy: 0.5346 - val_loss: 0.8932 - val_accuracy: 0.5250
# Epoch 32/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9231 - accuracy: 0.5205 - val_loss: 0.9017 - val_accuracy: 0.5333
# Epoch 33/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9141 - accuracy: 0.5231 - val_loss: 0.9108 - val_accuracy: 0.5208
# Epoch 34/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9137 - accuracy: 0.5285 - val_loss: 0.9527 - val_accuracy: 0.4958
# Epoch 35/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.9189 - accuracy: 0.5301 - val_loss: 0.9002 - val_accuracy: 0.5458
# Epoch 36/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.8986 - accuracy: 0.5473 - val_loss: 0.8743 - val_accuracy: 0.5542
# Epoch 37/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9005 - accuracy: 0.5383 - val_loss: 0.9293 - val_accuracy: 0.5479
# Epoch 38/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.9073 - accuracy: 0.5316 - val_loss: 0.8814 - val_accuracy: 0.5271
# Epoch 39/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.9063 - accuracy: 0.5290 - val_loss: 0.8726 - val_accuracy: 0.5250
# Epoch 40/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8887 - accuracy: 0.5396 - val_loss: 0.9014 - val_accuracy: 0.5312
# Epoch 41/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.9074 - accuracy: 0.5316 - val_loss: 0.8656 - val_accuracy: 0.5396
# Epoch 42/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8979 - accuracy: 0.5335 - val_loss: 0.8798 - val_accuracy: 0.5437
# Epoch 43/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8797 - accuracy: 0.5479 - val_loss: 0.8615 - val_accuracy: 0.5833
# Epoch 44/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8919 - accuracy: 0.5343 - val_loss: 0.8868 - val_accuracy: 0.5375
# Epoch 45/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8883 - accuracy: 0.5452 - val_loss: 0.8582 - val_accuracy: 0.5437
# Epoch 46/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8890 - accuracy: 0.5314 - val_loss: 0.9399 - val_accuracy: 0.5104
# Epoch 47/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8990 - accuracy: 0.5303 - val_loss: 0.8691 - val_accuracy: 0.5625
# Epoch 48/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8892 - accuracy: 0.5407 - val_loss: 0.8717 - val_accuracy: 0.5250
# Epoch 49/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.8712 - accuracy: 0.5527 - val_loss: 0.8882 - val_accuracy: 0.5562
# Epoch 50/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8718 - accuracy: 0.5590 - val_loss: 0.8654 - val_accuracy: 0.5750
# Epoch 51/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.8522 - accuracy: 0.5638 - val_loss: 0.8637 - val_accuracy: 0.5542
# Epoch 52/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8717 - accuracy: 0.5441 - val_loss: 0.8451 - val_accuracy: 0.5604
# Epoch 53/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8662 - accuracy: 0.5492 - val_loss: 0.9129 - val_accuracy: 0.5208
# Epoch 54/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8674 - accuracy: 0.5604 - val_loss: 0.9169 - val_accuracy: 0.5375
# Epoch 55/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8617 - accuracy: 0.5590 - val_loss: 0.8423 - val_accuracy: 0.5979
# Epoch 56/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8478 - accuracy: 0.5654 - val_loss: 0.8384 - val_accuracy: 0.5625
# Epoch 57/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8460 - accuracy: 0.5689 - val_loss: 0.8282 - val_accuracy: 0.5979
# Epoch 58/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.8613 - accuracy: 0.5636 - val_loss: 0.8881 - val_accuracy: 0.5396
# Epoch 59/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8503 - accuracy: 0.5705 - val_loss: 0.8375 - val_accuracy: 0.5979
# Epoch 60/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8421 - accuracy: 0.5742 - val_loss: 0.8326 - val_accuracy: 0.5521
# Epoch 61/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8316 - accuracy: 0.5777 - val_loss: 0.8524 - val_accuracy: 0.5458
# Epoch 62/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8405 - accuracy: 0.5699 - val_loss: 0.9084 - val_accuracy: 0.5167
# Epoch 63/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8387 - accuracy: 0.5737 - val_loss: 0.9248 - val_accuracy: 0.5229
# Epoch 64/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8336 - accuracy: 0.5843 - val_loss: 0.8529 - val_accuracy: 0.5417
# Epoch 65/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8281 - accuracy: 0.5801 - val_loss: 0.8291 - val_accuracy: 0.5479
# Epoch 66/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8490 - accuracy: 0.5593 - val_loss: 0.8404 - val_accuracy: 0.5375
# Epoch 67/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8211 - accuracy: 0.5793 - val_loss: 0.8188 - val_accuracy: 0.5896
# Epoch 68/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8221 - accuracy: 0.5771 - val_loss: 0.8079 - val_accuracy: 0.6167
# Epoch 69/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8263 - accuracy: 0.5803 - val_loss: 0.8563 - val_accuracy: 0.5521
# Epoch 70/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8291 - accuracy: 0.5763 - val_loss: 0.8240 - val_accuracy: 0.5896
# Epoch 71/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8129 - accuracy: 0.5819 - val_loss: 0.8894 - val_accuracy: 0.5396
# Epoch 72/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8296 - accuracy: 0.5707 - val_loss: 0.8087 - val_accuracy: 0.6062
# Epoch 73/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8239 - accuracy: 0.5758 - val_loss: 0.8095 - val_accuracy: 0.5667
# Epoch 74/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8156 - accuracy: 0.5864 - val_loss: 0.8899 - val_accuracy: 0.5333
# Epoch 75/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8152 - accuracy: 0.5840 - val_loss: 0.7864 - val_accuracy: 0.6083
# Epoch 76/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8026 - accuracy: 0.5928 - val_loss: 0.8413 - val_accuracy: 0.5604
# Epoch 77/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8277 - accuracy: 0.5771 - val_loss: 0.8073 - val_accuracy: 0.5917
# Epoch 78/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8075 - accuracy: 0.5840 - val_loss: 0.9306 - val_accuracy: 0.5000
# Epoch 79/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.8024 - accuracy: 0.5888 - val_loss: 0.8184 - val_accuracy: 0.5562
# Epoch 80/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8077 - accuracy: 0.5729 - val_loss: 0.9362 - val_accuracy: 0.5604
# Epoch 81/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7986 - accuracy: 0.5883 - val_loss: 0.8294 - val_accuracy: 0.5729
# Epoch 82/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7968 - accuracy: 0.5926 - val_loss: 0.8048 - val_accuracy: 0.5792
# Epoch 83/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.8028 - accuracy: 0.5931 - val_loss: 0.8299 - val_accuracy: 0.5792
# Epoch 84/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.8142 - accuracy: 0.5803 - val_loss: 0.9515 - val_accuracy: 0.5188
# Epoch 85/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7954 - accuracy: 0.6043 - val_loss: 0.7802 - val_accuracy: 0.6229
# Epoch 86/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7863 - accuracy: 0.6029 - val_loss: 0.7781 - val_accuracy: 0.6062
# Epoch 87/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.7751 - accuracy: 0.6162 - val_loss: 0.7719 - val_accuracy: 0.5958
# Epoch 88/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.7850 - accuracy: 0.6080 - val_loss: 0.7741 - val_accuracy: 0.5938
# Epoch 89/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.7976 - accuracy: 0.5957 - val_loss: 0.7918 - val_accuracy: 0.6062
# Epoch 90/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.7925 - accuracy: 0.5984 - val_loss: 0.7737 - val_accuracy: 0.6438
# Epoch 91/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7706 - accuracy: 0.6149 - val_loss: 0.7961 - val_accuracy: 0.5875
# Epoch 92/100
# 235/235 [==============================] - 15s 63ms/step - loss: 0.7639 - accuracy: 0.6149 - val_loss: 0.7551 - val_accuracy: 0.6646
# Epoch 93/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7873 - accuracy: 0.5995 - val_loss: 0.8556 - val_accuracy: 0.5604
# Epoch 94/100
# 235/235 [==============================] - 14s 58ms/step - loss: 0.7642 - accuracy: 0.6250 - val_loss: 0.7707 - val_accuracy: 0.6333
# Epoch 95/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7553 - accuracy: 0.6120 - val_loss: 0.7914 - val_accuracy: 0.5938
# Epoch 96/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7688 - accuracy: 0.6082 - val_loss: 0.7713 - val_accuracy: 0.6313
# Epoch 97/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7590 - accuracy: 0.6269 - val_loss: 0.8369 - val_accuracy: 0.5771
# Epoch 98/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7507 - accuracy: 0.6274 - val_loss: 0.7490 - val_accuracy: 0.6729
# Epoch 99/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7627 - accuracy: 0.6189 - val_loss: 0.7405 - val_accuracy: 0.6375
# Epoch 100/100
# 235/235 [==============================] - 14s 59ms/step - loss: 0.7874 - accuracy: 0.6040 - val_loss: 0.7510 - val_accuracy: 0.6500

# %%
#Plot epoch vs Accuracy and epoch vs Loss
accuracy = history1.history['accuracy']
val_accuracy = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

plt.figure(figsize=(12, 4))

plt.subplot(121)
plt.plot(range(epochs), accuracy, label='Training Accuracy')
plt.plot(range(epochs), val_accuracy, label='Validation Accuracy')
plt.title('Epoch vs. Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(122)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.title('Epoch vs. Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
scores1 = model1.evaluate(test_ds)
print(scores1)
acc = history1.history['accuracy']
print(acc)
val_acc = history1.history['val_accuracy']
print(val_acc)
loss = history1.history['loss']
print(loss)
val_loss = history1.history['val_loss']
print(val_loss)
# Out:
# 29/29 [==============================] - 42s 49ms/step - loss: 0.6650 - accuracy: 0.6875
# [0.6650264859199524, 0.6875]
# [0.35611701011657715, 0.4170212745666504, 0.4441489279270172, 0.44946807622909546, 0.4414893686771393, 0.4625000059604645, 0.4752659499645233, 0.4622340500354767, 0.4760638177394867, 0.4694148898124695, 0.47659575939178467, 0.486968070268631, 0.48803192377090454, 0.4827127754688263, 0.4835106432437897, 0.4904255270957947, 0.4893617033958435, 0.4864361584186554, 0.4888297915458679, 0.4936170279979706, 0.48750001192092896, 0.5029255151748657, 0.5045212507247925, 0.5106382966041565, 0.5095744729042053, 0.5202127695083618, 0.5127659440040588, 0.5055851340293884, 0.5234042406082153, 0.5247340202331543, 0.5345744490623474, 0.5204787254333496, 0.5231382846832275, 0.5284574627876282, 0.5300531983375549, 0.547340452671051, 0.5382978916168213, 0.5316489338874817, 0.5289893746376038, 0.5396276712417603, 0.5316489338874817, 0.5335106253623962, 0.5478723645210266, 0.5343084931373596, 0.5452127456665039, 0.5313829779624939, 0.5303191542625427, 0.5406914949417114, 0.5526595711708069, 0.5590425729751587, 0.563829779624939, 0.5441489219665527, 0.5492021441459656, 0.5603723526000977, 0.5590425729751587, 0.5654255151748657, 0.5688830018043518, 0.5635638236999512, 0.5704787373542786, 0.5742021203041077, 0.577659547328949, 0.569946825504303, 0.5736702084541321, 0.5843085050582886, 0.5800532102584839, 0.5593085289001465, 0.5792553424835205, 0.5771276354789734, 0.5803191661834717, 0.57632976770401, 0.5819149017333984, 0.5707446932792664, 0.5757978558540344, 0.5864361524581909, 0.5840425491333008, 0.5928191542625427, 0.5771276354789734, 0.5840425491333008, 0.5888298153877258, 0.5728723406791687, 0.5882978439331055, 0.5925531983375549, 0.5930851101875305, 0.5803191661834717, 0.6042553186416626, 0.6029255390167236, 0.6162233948707581, 0.6079787015914917, 0.5957446694374084, 0.5984042286872864, 0.6148936152458191, 0.6148936152458191, 0.5994681119918823, 0.625, 0.6119681000709534, 0.6082446575164795, 0.6268616914749146, 0.6273936033248901, 0.618882954120636, 0.6039893627166748]
# [0.39791667461395264, 0.47083333134651184, 0.4749999940395355, 0.47708332538604736, 0.4645833373069763, 0.46875, 0.47708332538604736, 0.48124998807907104, 0.4958333373069763, 0.4854166805744171, 0.46875, 0.4937500059604645, 0.4895833432674408, 0.4833333194255829, 0.4958333373069763, 0.4479166567325592, 0.4937500059604645, 0.5083333253860474, 0.5, 0.46666666865348816, 0.5020833611488342, 0.4895833432674408, 0.5208333134651184, 0.5062500238418579, 0.5249999761581421, 0.5208333134651184, 0.5291666388511658, 0.5229166746139526, 0.5270833373069763, 0.53125, 0.5249999761581421, 0.5333333611488342, 0.5208333134651184, 0.4958333373069763, 0.5458333492279053, 0.5541666746139526, 0.5479166507720947, 0.5270833373069763, 0.5249999761581421, 0.53125, 0.5395833253860474, 0.543749988079071, 0.5833333134651184, 0.5375000238418579, 0.543749988079071, 0.5104166865348816, 0.5625, 0.5249999761581421, 0.5562499761581421, 0.574999988079071, 0.5541666746139526, 0.5604166388511658, 0.5208333134651184, 0.5375000238418579, 0.5979166626930237, 0.5625, 0.5979166626930237, 0.5395833253860474, 0.5979166626930237, 0.5520833134651184, 0.5458333492279053, 0.5166666507720947, 0.5229166746139526, 0.5416666865348816, 0.5479166507720947, 0.5375000238418579, 0.5895833373069763, 0.6166666746139526, 0.5520833134651184, 0.5895833373069763, 0.5395833253860474, 0.606249988079071, 0.5666666626930237, 0.5333333611488342, 0.6083333492279053, 0.5604166388511658, 0.5916666388511658, 0.5, 0.5562499761581421, 0.5604166388511658, 0.5729166865348816, 0.5791666507720947, 0.5791666507720947, 0.518750011920929, 0.6229166388511658, 0.606249988079071, 0.5958333611488342, 0.59375, 0.606249988079071, 0.643750011920929, 0.5874999761581421, 0.6645833253860474, 0.5604166388511658, 0.6333333253860474, 0.59375, 0.6312500238418579, 0.5770833492279053, 0.6729166507720947, 0.637499988079071, 0.6499999761581421]
# [1.1012922525405884, 1.0645302534103394, 1.0435967445373535, 1.0190473794937134, 1.0167384147644043, 1.0040440559387207, 1.0017809867858887, 0.9979408383369446, 0.9877838492393494, 0.9883038997650146, 0.9891908764839172, 0.9789147973060608, 0.9780222177505493, 0.9778193831443787, 0.970466673374176, 0.9636601209640503, 0.9774841070175171, 0.9623950719833374, 0.9668207764625549, 0.9582517147064209, 0.9566420316696167, 0.953652560710907, 0.951645016670227, 0.9346307516098022, 0.939896285533905, 0.9302541017532349, 0.9366057515144348, 0.9289697408676147, 0.9215744733810425, 0.922869861125946, 0.9187175631523132, 0.923125684261322, 0.9140594005584717, 0.913686215877533, 0.9188941717147827, 0.8985501527786255, 0.9004698395729065, 0.9073042273521423, 0.9063089489936829, 0.8887444138526917, 0.9074336290359497, 0.8979492783546448, 0.8797046542167664, 0.8918569087982178, 0.8882855772972107, 0.8889844417572021, 0.8989853262901306, 0.8892155885696411, 0.8711890578269958, 0.8718125224113464, 0.8521615266799927, 0.8716981410980225, 0.8661510944366455, 0.8674373626708984, 0.8616838455200195, 0.8478440046310425, 0.845952570438385, 0.8612985610961914, 0.8502659797668457, 0.842078685760498, 0.8316008448600769, 0.8404778242111206, 0.8387224674224854, 0.8336356282234192, 0.8281241655349731, 0.8490137457847595, 0.8210816979408264, 0.8220624327659607, 0.8263242840766907, 0.8290681838989258, 0.8129318356513977, 0.8296190500259399, 0.8239421248435974, 0.815565288066864, 0.8152374029159546, 0.8025822639465332, 0.8276727795600891, 0.8074755072593689, 0.8023958802223206, 0.8076608777046204, 0.7986473441123962, 0.7967793345451355, 0.802793562412262, 0.8142201900482178, 0.7954344153404236, 0.7862595319747925, 0.7751362919807434, 0.7850047945976257, 0.7975987195968628, 0.7924739122390747, 0.7705661654472351, 0.7638868689537048, 0.7873123288154602, 0.7642036080360413, 0.7552812099456787, 0.7688149809837341, 0.7590144276618958, 0.7507283091545105, 0.7627184391021729, 0.7873939275741577]
# [1.0800551176071167, 1.0226908922195435, 1.0066765546798706, 1.0128387212753296, 0.990145742893219, 0.9740737080574036, 0.9874314665794373, 0.977202296257019, 0.9641200304031372, 0.9807599782943726, 0.9624661803245544, 0.9572232365608215, 0.9472818374633789, 0.9797379374504089, 0.9618400931358337, 1.011881709098816, 0.9556583762168884, 0.9380236268043518, 0.965409517288208, 0.9621010422706604, 0.9351950883865356, 0.9424402713775635, 0.9250013828277588, 0.942282497882843, 0.920753538608551, 0.9326258897781372, 0.9268236756324768, 0.920684278011322, 0.9049285054206848, 0.9018974900245667, 0.8932133913040161, 0.9017263650894165, 0.910807728767395, 0.9527156949043274, 0.9002029895782471, 0.8742752075195312, 0.9292850494384766, 0.8814278841018677, 0.8725544810295105, 0.9014224410057068, 0.8655834197998047, 0.8797867298126221, 0.8614698648452759, 0.8868318200111389, 0.8582310080528259, 0.9398888945579529, 0.8690719604492188, 0.8717300295829773, 0.8882384896278381, 0.8654171824455261, 0.8637061715126038, 0.8451250791549683, 0.912904679775238, 0.9168888926506042, 0.8422706127166748, 0.8383599519729614, 0.8281896114349365, 0.8881114721298218, 0.8374616503715515, 0.8325520753860474, 0.8524333834648132, 0.9083848595619202, 0.9248036742210388, 0.8528850674629211, 0.8291231989860535, 0.8403765559196472, 0.8188262581825256, 0.8078657984733582, 0.8562719821929932, 0.8239799737930298, 0.8894121646881104, 0.8086626529693604, 0.8094829320907593, 0.8898901343345642, 0.7863693833351135, 0.8412578105926514, 0.8072699308395386, 0.9305623173713684, 0.8183683753013611, 0.9362390041351318, 0.8293613791465759, 0.8048473000526428, 0.8299056887626648, 0.9514749050140381, 0.7802091240882874, 0.7780510187149048, 0.7719412446022034, 0.7741098999977112, 0.7918087840080261, 0.7736810445785522, 0.7960573434829712, 0.7550638318061829, 0.8556196689605713, 0.7707095742225647, 0.7914056181907654, 0.7713268995285034, 0.8369129300117493, 0.7490198016166687, 0.7404607534408569, 0.7510112524032593]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) #create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100*(np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(BATCH_SIZE):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence = predict(model1, images[i].numpy())

        actual_class = class_names[labels[i]]

        plt.title(f"Actual Class : {actual_class}, \n Predicted Class: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 61ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e6388812cd87> in <cell line: 2>()
#       2 for images, labels in test_ds.take(1):
#       3     for i in range(BATCH_SIZE):
# ----> 4         ax = plt.subplot(3, 3, i+1)
#       5         plt.imshow(images[i].numpy().astype("uint8"))
#       6         predicted_class, confidence = predict(model1, images[i].numpy())
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1321
#    1322     # First, search for an existing subplot with a matching spec.
# -> 1323     key = SubplotSpec._from_subplot_args(fig, args)
#    1324
#    1325     for ax in fig.axes:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     596         else:
#     597             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598                 raise ValueError(
#     599                     f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600                     f"not {num!r}"
#
# ValueError: num must be an integer with 1 <= num <= 9, not 10

# %%
y_pred = []  # store predicted labels
y_true = []  # store true labels

for image_batch, label_batch in test_ds:
  y_true.append(label_batch)
  preds = model1.predict(image_batch)
  y_pred.append(np.argmax(preds, axis=-1))

correct_labels = tf.concat([item for item in y_true], axis=0)
predicted_labels = tf.concat([item for item in y_pred], axis=0)
conf_matrix = confusion_matrix(correct_labels, predicted_labels)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
print(classification_report( correct_labels, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       161
#            1       0.56      0.68      0.62       152
#            2       0.68      0.63      0.66       151
#
#     accuracy                           0.69       464
#    macro avg       0.70      0.69      0.69       464
# weighted avg       0.71      0.69      0.69       464

# %%
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve, auc

# %%
conf_mat = confusion_matrix(correct_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
print("Mean Absolute Error:" , mean_absolute_error(correct_labels,predicted_labels))
# Out:
# Mean Absolute Error: 0.3448275862068966

# %%
print("Mean Squared Error:" , mean_squared_error(correct_labels,predicted_labels))
# Out:
# Mean Squared Error: 0.40948275862068967

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# ...

# Get predicted probabilities for each class
y_prob = model1.predict(test_ds)

# Convert true labels to one-hot encoding
y_true_one_hot = tf.keras.utils.to_categorical(correct_labels, num_classes=num_classes)

# Calculate AUC for each class
auc_scores = []
for i in range(num_classes):
    auc_score = roc_auc_score(y_true_one_hot[:, i], y_prob[:, i])
    auc_scores.append(auc_score)

# Plot ROC curve for each class
plt.figure(figsize=(12, 8))
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_one_hot[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {auc_scores[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Each Class')
plt.legend()
plt.show()
# Out:
# 29/29 [==============================] - 2s 45ms/step

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

# ...

# Get predicted probabilities for each class
y_prob = model1.predict(test_ds)

# Convert true labels to one-hot encoding
y_true_one_hot = tf.keras.utils.to_categorical(correct_labels, num_classes=num_classes)

# Calculate micro-average AUC score
micro_auc_score = roc_auc_score(y_true_one_hot, y_prob, average='micro')

# Calculate macro-average AUC score
macro_auc_score = roc_auc_score(y_true_one_hot, y_prob, average='macro')

print(f'Micro-average AUC Score: {micro_auc_score:.4f}')
print(f'Macro-average AUC Score: {macro_auc_score:.4f}')
# Out:
# 29/29 [==============================] - 1s 46ms/step
# Micro-average AUC Score: 0.5220
# Macro-average AUC Score: 0.5214
